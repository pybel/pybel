# %%
import pybel
import logging
import os
import networkx as nx
import nx2d3
import logging
from operator import itemgetter
from collections import Counter
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib inline

# %%
g = pybel.from_bel('~/Desktop/AD.bel')
# Out:
# PyBEL000 general parser failure: a(ADO:"Abeta_42") hasMembers list (a(ADO:"Abeta_42"),a(ADO:"Abeta_40"))
# PyBEL000 general parser failure: reaction(reactants(a(CHEBI:superoxide), a(CHEBI:"hydrogen peroxide")),products(a(isoprostanes)))
# PyBEL000 general parser failure: enzyme widely distributed in the central nervous system, and it has been involved in the neurobiology of Alzheimer disease (AD)"
# PyBEL000 general parser failure: p(PMICOMP:"mTOR-FKBP12-rapamycin complex") hasMembers list (p(HGNC:LRP1),p(HGNC:LRP2),p(HGNC:LRP3),p(HGNC:LRP4),p(HGNC:LRP5),p(HGNC:LRP6),p(HGNC:LRP8),p(HGNC:LRP10),p(HGNC:LRP11))
# PyBEL000 general parser failure: complex(p(HGNC:APP),p(HGNC:APBA1,sub(T))) -> a(ADO:"Abeta_42")
# PyBEL000 general parser failure: p(HGNC:GSK3B,sub(T)) -> deg(p(HGNC:APP))
# PyBEL000 general parser failure: a(C31) -> act(p(HGNC:CASP3))
# PyBEL000 general parser failure: a(C31) -> a(ADO:"Abeta_42")
# PyBEL000 general parser failure: a(CHEBI:ganglioside) hasMembers list(a(CHEBI:"GM1 ganglioside"),a(CHEBIID:59228),a(CHEBIID:59222),a(CHEBI:"ganglioside GT1b"))
# PyBEL000 general parser failure: p(HGNC:CST3,sub(T,25)) -| p(HGNC:CST3)
# PyBEL000 general parser failure: p(HGNC:CST3,sub(T,25)) -> path(MESHD:"Alzheimer Disease")
# PyBEL000 general parser failure: Ca2+ pumps)"
# PyBEL000 general parser failure: a(PMIPFAM:"Kainate Family")hasMembers list(p(HGNC:GRIK1),p(HGNC:GRIK2),p(HGNC:GRIK3),p(HGNC:GRIK4),p(HGNC:GRIK5))
# PyBEL000 general parser failure: a("NMDA Receptors") hasMembers list(p(HGNC:GRIN2A),p(HGNC:GRIN2B),p(HGNC:GRIN2C),p(HGNC:GRIN2D),p(HGNC:GRIN3A),p(HGNC:GRIN3B),p(HGNC:GRIN1))
# PyBEL000 general parser failure: a("NMDA Receptors") -> bp(GOBP:"regulation of N-methyl-D-aspartate selective glutamate receptor activity")
# PyBEL000 general parser failure: complex(a(CHEBI:"glutamate(2-)"),a("NMDA Receptors")) -- bp(GOBP:"positive regulation of synaptic transmission, glutamatergic")
# PyBEL000 general parser failure: complex(a(CHEBI:"glutamate(1-)"),a("NMDA Receptors")) -- bp(GOBP:"positive regulation of synaptic transmission, glutamatergic")
# PyBEL000 general parser failure: act(a("NMDA Receptors")) -> bp(GOBP:"neuron apoptotic process")
# PyBEL000 general parser failure: act(a("NMDA Receptors")) -| bp(GOBP:"calcium channel regulator activity")
# PyBEL000 general parser failure: act(a("NMDA Receptors")) -> bp(GOBP:"calcium ion import")
# PyBEL000 general parser failure: act(a("NMDA Receptors")) -> a(CHEBI:"nitric oxide")
# PyBEL000 general parser failure: act(a("NMDA Receptors")) -> bp(GOBP:"negative regulation of calcium-mediated signaling")
# PyBEL000 general parser failure: a("ryanodine receptors") hasMembers list(p(HGNC:RYR2),p(HGNC:RYR1),p(HGNC:RYR3))
# PyBEL000 general parser failure: complex(p(HGNC:PSEN1),a("ryanodine receptors")) -> bp(GOBP:"regulation of ryanodine-sensitive calcium-release channel activity")
# PyBEL000 general parser failure: tloc(a(BRCO:Microglia), "Bone Marrow Cells", "Brain") -| path(MESHD:"Alzheimer Disease")
# PyBEL000 general parser failure: a("Monocyte-Macrophage Precursor Cells") -- a(ADO:"Abeta_42")
# PyBEL000 general parser failure: complex(a(Monocytes),p(HGNC:TNF)) -> bp(GOBP:"maintenance of blood-brain barrier")
# PyBEL000 general parser failure: p(Cathepsins) hasMembers list(p(HGNC:CTSA),p(HGNC:CTSB),p(HGNC:CTSC),p(HGNC:CTSD),p(HGNC:CTSE),p(HGNC:CTSF),p(HGNC:CTSG),p(HGNC:CTSL))
# PyBEL000 general parser failure: p(SFAM:"IRS Family") hasMembers list(p(HGNC:IRS1),p(HGNC:IRS2),p(HGNC:IRS4))
# PyBEL000 general parser failure: deg(a (Neurons)) -- bp(GOBP:cognition)
# PyBEL000 general parser failure: p(SFAM:"PRKAA Family") hasMembers list(p(HGNC:PRKAA1),p(HGNC:PRKAA2))
# PyBEL000 general parser failure: bp("cerebral perfusion") -> act(g(HGNC:APP))
# PyBEL000 general parser failure: bp("cerebral perfusion") -> a(ADO:"Abeta_42")
# PyBEL000 general parser failure: complex(p(HGNC:IDE),a(ubiquitin)) -| act(p(HGNC:IDE))
# PyBEL000 general parser failure: act(a(NMDAR)) -> bp(MESHPP:"Long-Term Potentiation")
# PyBEL000 general parser failure: m(HGNC:MIR20A) hasMembers list (m(HGNC:MIR17),m(HGNC:MIR106B))
# PyBEL000 general parser failure: a(AC253) -| a(SCHEM:Calcium)
# PyBEL000 general parser failure: a(AC253) -| bp(GOBP:"MAP kinase activity")
# PyBEL000 general parser failure: a(AC253) -| p(SFAM:"AKT Family")
# PyBEL000 general parser failure: a(AC253) -| p(HGNC:FOS)
# PyBEL000 general parser failure: complex(a("Amylin receptor"),p(HGNC:IAPP)) -> act(a("Amylin receptor"))
# PyBEL000 general parser failure: complex(a("Amylin receptor"),a(ADO:"Abeta_42")) -> act(a("Amylin receptor"))
# PyBEL000 general parser failure: act(a("Amylin receptor")) -> act(a(AC253))
# PyBEL000 general parser failure: act(a("Amylin receptor")) -> act(a(AC253))
# PyBEL000 general parser failure: complex(SCOMP:"gamma Secretase Complex") hasMembers list(p(HGNC:NCSTN),p(HGNC:APH1B),p(HGNC:PSEN2),p(HGNC:PSEN1),p(HGNC:PSENEN))
# PyBEL000 general parser failure: p(SFAM:"ADRA Family") hasMembers list(p(HGNC:ADRA1A),p(HGNC:ADRA1B),p(HGNC:ADRA1D),p(HGNC:ADRA2A),p(HGNC:ADRA2B),p(HGNC:ADRA2C))
# PyBEL000 general parser failure: a(PMICHEM:cerebrolysin) hasMembers list(p(HGNC:BDNF),p(HGNC:GDNF),p(HGNC:NGF),p(HGNC:CNTF))
# PyBEL000 general parser failure: p(HGNC:GRIA1) hasMembers list(p(HGNC:GRIA1), p(HGNC:GRIA2), p(HGNC:GRIA3), p(HGNC:GRIA4))
# PyBEL000 general parser failure: complex(a(CHEBI:galanthamine), p(nAChRs)) -> act(p(nAChRs))
# PyBEL000 general parser failure: p(SFAM:"ADRB Family") hasMembers list(p(HGNC:ADRB1),p(HGNC:ADRB2),p(HGNC:ADRB3))
# PyBEL000 general parser failure: p("cholinergic receptor") hasMembers list(p(nAChRs),p(mAChRs))
# PyBEL000 general parser failure: p(nAChRs) hasMembers list(p(HGNC:CHRNA2), p(HGNC:CHRNA3), p(HGNC:CHRNA4), p(HGNC:CHRNA5), p(HGNC:CHRNA6), p(HGNC:CHRNA7), p(HGNC:CHRNA9),
# PyBEL000 general parser failure: p(mAChRs) hasMembers list(p(HGNC:CHRM1), p(HGNC:CHRM2), p(HGNC:CHRM3), p(HGNC:CHRM4), p(HGNC:CHRM5))
# PyBEL000 general parser failure: p("GABA receptor") hasMembers list(p("GABAA receptor"), p("GABAB receptor"))
# PyBEL000 general parser failure: p("GABAA receptor") hasMembers list(p(HGNC:GABRA1), p(HGNC:GABRA2), p(HGNC:GABRA3), p(HGNC:GABRA4), p(HGNC:GABRA5), p(HGNC:GABRA6),
# PyBEL000 general parser failure: p("GABAB receptor") hasMembers list(p(HGNC:GABBR1), p(HGNC:GABBR2))
# PyBEL000 general parser failure: p("dopaminergic receptor") hasMembers list(p(HGNC:DRD1), p(HGNC:DRD2), p(HGNC:DRD3), p(HGNC:DRD4), p(HGNC:DRD5))
# PyBEL000 general parser failure: p("histamine receptor") hasMembers list(p(HGNC:HRH1), p(HGNC:HRH2), p(HGNC:HRH3), p(HGNC:HRH4))
# PyBEL000 general parser failure: p(HGNC:ADRA1A)hasMembers list(p(HGNC:ADRA1A),p(HGNC:ADRA1B),p(HGNC:ADRA1D),p(HGNC:ADRA2A),p(HGNC:ADRA2B),p(HGNC:ADRA2C))
# PyBEL000 general parser failure: p(HGNC:ADRB2) hasMembers list(p(HGNC:ADRB1),p(HGNC:ADRB2),p(HGNC:ADRB3))
# PyBEL000 general parser failure: p(mAChRs) hasMembers list(p(HGNC:CHRM1), p(HGNC:CHRM2), p(HGNC:CHRM3), p(HGNC:CHRM4), p(HGNC:CHRM5))
# PyBEL000 general parser failure: act(complex("HPA axis")) -> a(CHEBI:corticotropin)
# PyBEL000 general parser failure: act(complex("HPA axis")) -> a(CHEBI:cortisol)
# PyBEL000 general parser failure: act(complex("HPA axis")) -> a(CHEBI:vasopressin)
# PyBEL000 general parser failure: act(complex("HPA axis")) -> a(SCHEM:Epinephrine)
# PyBEL000 general parser failure: a(Neuropeptide) hasMembers list(a(CHEBI:corticotropin),a(CHEBI:cortisol), a(CHEBI:vasopressin), a(SCHEM:Epinephrine))
# PyBEL000 general parser failure: a(Neuropeptide) -> bp(GOBP:"synaptic transmission")
# PyBEL000 general parser failure: a(Neuropeptide) -> bp(GOBP:cognition)
# PyBEL000 general parser failure: p(HGNC:GRIN2B) hasMembers list(p(HGNC:GRIN1), p(HGNC:GRIN2A), p(HGNC:GRIN2B), p(HGNC:GRIN2C), p(HGNC:GRIN2D), p(HGNC:GRIN3A), p(HGNC:GRIN3B))
# PyBEL000 general parser failure: p(nAChRs) hasMembers list(p(HGNC:CHRNA2), p(HGNC:CHRNA3), p(HGNC:CHRNA4), p(HGNC:CHRNA5), p(HGNC:CHRNA6), p(HGNC:CHRNA7), p(HGNC:CHRNA9),
# PyBEL000 general parser failure: act(p(nAChRs)) -> a(CHEBI:"gamma-aminobutyric acid")
# PyBEL000 general parser failure: act(p(nAChRs)) -> a(CHEBI:"glutamate(1-)")
# PyBEL000 general parser failure: p(HGNC:PRKCA) hasMembers list(p(HGNC:PRKCA), p(HGNC:PRKCB), p(HGNC:PRKCD), p(HGNC:PRKCE), p(HGNC:PRKCG), p(HGNC:PRKCH), p(HGNC:PRKCI), p(HGNC:PRKCQ), p(HGNC:PRKCZ))
# PyBEL000 general parser failure: act(p(nAChRs)) -> a(CHEBI:"glutamate(1-)")
# PyBEL000 general parser failure: complex(SCOMP:"Nfkb Complex") hasMembers list(p(HGNC:RELA), p(HGNC:NFKB1))
# PyBEL000 general parser failure: p(nAChRs) hasMembers list(p(HGNC:CHRNA2), p(HGNC:CHRNA3), p(HGNC:CHRNA4), p(HGNC:CHRNA5), p(HGNC:CHRNA6), p(HGNC:CHRNA7), p(HGNC:CHRNA9),
# PyBEL000 general parser failure: bp(PTS:nuclear factor kappa B signaling pathway) -> p(HGNC:BACE1)
# PyBEL000 general parser failure: bp(PTS:nuclear factor kappa B signaling pathway) -- path(MESHD:Inflammation)
# PyBEL000 general parser failure: bp(PTS:nuclear factor kappa B signaling pathway) -> p(HGNC:BACE1)
# PyBEL000 general parser failure: p(HGNC:NFKB1) hasMembers list(p(HGNC:RELA), p(HGNC:NFKB1))
# PyBEL000 general parser failure: p("GABAA receptor") hasMembers list(p(HGNC:GABRA1), p(HGNC:GABRA2), p(HGNC:GABRA3), p(HGNC:GABRA4), p(HGNC:GABRA5), p(HGNC:GABRA6),
# PyBEL000 general parser failure: p("GABAA receptor") -- bp(GOBP:"regulation of synaptic plasticity")
# PyBEL000 general parser failure: p(FIXME) -- a(CHEBI:losartan)
# PyBEL000 general parser failure: p(nAChRs) hasMembers list(p(RGD:Chrna2), p(RGD:Chrna3), p(RGD:Chrna4), p(RGD:Chrna5), p(RGD:Chrna6), p(RGD:Chrna7), p(RGD:Chrna9), p(RGD:Chrna10), p(RGD:Chrnb2), p(RGD:Chrnb3), p(RGD:Chrnb4))
# PyBEL000 general parser failure: p(FIXME) -- p(HGNC:XIAP)
# PyBEL000 general parser failure: p(SFAM:"HSP70 Family") hasMembers list(p(HGNC:HSPA1A),p(HGNC:HSPA1B),p(HGNC:HSPA1L))
# PyBEL000 general parser failure: p(SFAM:"MAPK Erk1/2 Family") hasMembers list(p(HGNC:MAPK11),p(HGNC:MAPK12),p(HGNC:MAPK13),p(HGNC:MAPK14))
# PyBEL000 general parser failure: p(SFAM:"MAPK Erk1/2 Family") hasMembers list(p(HGNC:MAPK1),p(HGNC:MAPK3))
# PyBEL000 general parser failure: p(SFAM:"MAPK Erk1/2 Family") hasMembers list(p(HGNC:MAPK1),p(HGNC:MAPK3))
# PyBEL000 general parser failure: p(HGNC:NFKB1) hasMembers list(p(HGNC:NFKB1),p(HGNC:NFKB2))
# PyBEL000 general parser failure: p(HGNC:GRIA1) hasMembers list(p(HGNC:GRIA1), p(HGNC:GRIA2), p(HGNC:GRIA3), p(HGNC:GRIA4))
# PyBEL000 general parser failure: p(HGNC:GRIN2B) hasMembers list(p(HGNC:GRIN1), p(HGNC:GRIN2A), p(HGNC:GRIN2B), p(HGNC:GRIN2C), p(HGNC:GRIN2D), p(HGNC:GRIN3A), p(HGNC:GRIN3B))
# PyBEL000 general parser failure: p("GABAA receptor") hasMembers list(p(HGNC:GABRA1), p(HGNC:GABRA2), p(HGNC:GABRA3), p(HGNC:GABRA4), p(HGNC:GABRA5), p(HGNC:GABRA6),
# PyBEL000 general parser failure: p(SFAM:"Mapk p38 Family") hasMembers list(p(MGI:Mapk11),p(MGI:Mapk12),p(MGI:Mapk13),p(MGI:Mapk14))
# PyBEL000 general parser failure: a(ADO:"Abeta_42") hasMembers list (a(ADO:"Abeta_42"),a(ADO:"Abeta_40"))
# PyBEL000 general parser failure: complex(a(ADO:neuroprotectin), a(Neutrophils))
# PyBEL000 general parser failure: a("anti-RAGE F(ab')2") -| p(HGNC:CSF1)
# PyBEL000 general parser failure: a(sulfatides) -- path(MESHD:"Alzheimer Disease")
# PyBEL000 general parser failure: a(sulfatides) -> complex(p(HGNC:APOE),a(ADO:"Abeta_42"))
# PyBEL000 general parser failure: a("RAB5A mutant") -| complex(p(HGNC:BACE1),p(HGNC:APP))
# PyBEL000 general parser failure: a("RAB5A mutant") -| a(ADO:"Abeta_42")
# PyBEL000 general parser failure: complex(a(C99),p(HGNC:PSEN1))
# PyBEL000 general parser failure: p(MAPT,pmod(P)) -- path(MESHD:"Alzheimer Disease")
# PyBEL000 general parser failure: p(MAPK14,pmod(P)) -| p(HGNC:CDH2)
# PyBEL000 general parser failure: p(SFAM:"NTRK Family") hasMembers list(p(HGNC:NTRK3),p(HGNC:NTRK2),p(HGNC:NTRK1))
# PyBEL000 general parser failure: a("misfolded proteins") -> bp(GOBP:"endoplasmic reticulum unfolded protein response")
# PyBEL000 general parser failure: bp("cellular stress response") -| p(MGI:Hspa5)
# PyBEL000 general parser failure: complex(r(17A),p(HGNC:GBRR2))
# PyBEL000 general parser failure: r(17A) -| bp(GOBP:"gamma-aminobutyric acid signaling pathway")
# PyBEL000 general parser failure: r(17A) -> a(ADO:"Abeta_42")
# PyBEL000 general parser failure: p(PMIPFAM:"NRXN Family") hasMembers list (p(HGNC:NRXN1),p(HGNC:NRXN3))
# PyBEL000 general parser failure: a("Humanin") negativeCorrelation path(MESHD:"Alzheimer's disease")
# PyBEL000 general parser failure: complex(a("Humanin"), p(HGNC:MPHOSPH8))
# PyBEL000 general parser failure: reaction(reactants(a("alpha-ketogluterate")), products(a(CHEBI:"succinyl-CoA"))) -> bp(GOBP:"tricarboxylic acid cycle")
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -| p(HGNC:UCHL1)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -| act(p(HGNC:NTRK2))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -| act(p(HGNC:BDNF))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") =| complex(p(HGNC:BDNF),p(HGNC:NTRK2))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -| (act(p(HGNC:NTRK2)) -> bp(GO:"neuron development"))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -| (act(p(HGNC:BDNF)) -> bp(GO:"axon cargo transport"))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") =| (complex(p(HGNC:BDNF),p(HGNC:NTRK2)) -> bp(GO:"neuron development"))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") =| (complex(p(HGNC:BDNF),p(HGNC:NTRK2)) -> bp(GO:"neuron homeostasis"))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") =| (complex(p(HGNC:BDNF),p(HGNC:NTRK2)) -> act(p(HGNC:NTRK2)))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") =| complex(p(HGNC:BDNF),p(HGNC:NTRK2))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -| r(HGNC:UCHL1)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -| (r(HGNC:UCHL1) -> act(p(HGNC:BDNF)))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -| (r(HGNC:UCHL1) -> bp(GO:"retrograde axon cargo transport"))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -| (act(p(HGNC:BDNF)) -> bp(GO:"regulation of neuronal synaptic plasticity"))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -| (act(p(HGNC:BDNF)) -> bp(GO:"neuron development"))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> path(MESHD:"Alzheimer Disease")
# PyBEL000 general parser failure: complex(a("Amyloid beta-Peptides"),p(HGNC:NGFR)) -> bp(GO:"neuron death")
# PyBEL000 general parser failure: complex(a("Amyloid beta-Peptides"),p(HGNC:NGFR)) -| complex(p(HGNC:NGF),p(HGNC:NGFR))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -| p(HGNC:NGFR,pmod(U))
# PyBEL000 general parser failure: complex(a("Amyloid beta-Peptides"),p(HGNC:NGFR)) -| p(HGNC:NGFR,pmod(U))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -| act(p(HGNC:NFKB1))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -| complex(p(HGNC:NGFR),p(HGNC:IKBKB))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> path(MESHD:"Alzheimer Disease")
# PyBEL000 general parser failure: complex(a("Amyloid beta-Peptides"),p(HGNC:NGFR)) -> bp(GO:"neuron death")
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -| p(HGNC:NGFR,pmod(U))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -| act(p(HGNC:NFKB1))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -| complex(p(HGNC:NGFR),p(HGNC:IKBKB))
# PyBEL000 general parser failure: composite(p(HGNC:PSEN1),p(HGNC:PSEN2),a("Amyloid beta-Peptides")) -| bp(GO:"calcium ion homeostasis")
# PyBEL000 general parser failure: composite(p(HGNC:PSEN1),p(HGNC:PSEN2),a("Amyloid beta-Peptides")) -| bp(GO:"synaptic transmission")
# PyBEL000 general parser failure: complex(a(p(HGNC:DIAPH1)),act(p(HGNC:RAGE)),a(p(HGNC:S100B))) -> bp(GO:"telencephalon microglial cell migration")
# PyBEL000 general parser failure: a("Amyloid beta-Peptides")  -> p(HGNC:MAPT,pmod(P))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> act(p(HGNC:GSK3B))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> bp(GO:"neuron apoptotic process")
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> act(p(HGNC:GSK3B))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -| tscript(p(HGNC:CREBBP))
# PyBEL000 general parser failure: a(AICD) -> act(p(HGNC:TP53))
# PyBEL000 general parser failure: a(AICD) -> act(p(HGNC:GSK3B))
# PyBEL000 general parser failure: a(AICD) -> p(HGNC:DPYSL2,pmod(P))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> act(p(complex(NCH:"Calcineurin Complex")))
# PyBEL000 general parser failure: act(p(complex(NCH:"Calcineurin Complex"))) -| p(HGNC:BAD,pmod(P))
# PyBEL000 general parser failure: act(p(complex(NCH:"Calcineurin Complex"))) -> bp(GO:"cell death")
# PyBEL000 general parser failure: act(p(complex(NCH:"Calcineurin Complex"))) -| p(PFH:"CREB Family",pmod(P))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -| act(p(HGNC:NTRK2))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -| act(p(HGNC:BDNF))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -| bp(GO:"axon transport of mitochondria")
# PyBEL000 general parser failure: composite(bp(GO:"calcium ion import"),kin(p(HGNC:SKAP1)))-> p(HGNC:GRINA)
# PyBEL000 general parser failure: tloc(HGNC:APP) -| a("Amyloid beta-Peptides")
# PyBEL000 general parser failure: kin(PFH:"MAPK JNK Family") -> p(HGNC:APP,pmod(P,668,T))
# PyBEL000 general parser failure: p(HGNC:APP,pmod(P,668,T)) -> a("Amyloid beta-Peptides")
# PyBEL000 general parser failure: a("sAPP-alpha") -> bp(GO:"regulation of neuronal synaptic plasticity")
# PyBEL000 general parser failure: a("sAPP-alpha") -> bp(GO:"stem cell proliferation")
# PyBEL000 general parser failure: a("sAPP-alpha") -> bp(GO:"central nervous system development")
# PyBEL000 general parser failure: a("sAPP-alpha") -| p(HGNC:CDK5)
# PyBEL000 general parser failure: translocation(a("Amyloid beta-Peptides"),MESHCL:Brain,MESHCL:Blood) =| a("Amyloid beta-Peptides")
# PyBEL000 general parser failure: a(Microglia) -> deg(a("Amyloid beta-Peptides"))
# PyBEL000 general parser failure: a(Astrocytes) -> deg(a("Amyloid beta-Peptides"))
# PyBEL000 general parser failure: tloc(a("Amyloid beta-Peptides"), MESHCL:"COP-Coated Vesicles", MESHCL:Lysosomes) -> deg(a("Amyloid beta-Peptides"))
# PyBEL000 general parser failure: complex(p(HGNC:LDLR),a("Amyloid beta-Peptides")) -> deg(a("Amyloid beta-Peptides"))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> bp(GO:"hormone binding")
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> bp(GO:"hormone secretion")
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -- bp(GO:"ion channel activity")
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -- bp(GO:"neuron homeostasis")
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -- bp(GO:"synaptic transmission")
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -| bp(GO:"synaptic transmission")
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> bp(GO:"regulation of neuronal synaptic plasticity")
# PyBEL000 general parser failure: complex(a("Amyloid beta-Peptides"),p(HGNC:INSR)) -> act(p(HGNC:PDK1))
# PyBEL000 general parser failure: complex(a("Amyloid beta-Peptides"),p(HGNC:INSR)) -> p(HGNC:AKT2)
# PyBEL000 general parser failure: composite(act(p(HGNC:RPS6KA1),p(HGNC:RPS6KA5),p(HGNC:RPS6KA4))) -> tscript(p(PFH:"CREB Family"))
# PyBEL000 general parser failure: complex(a("Amyloid beta-Peptides"),p(PFH:"Cholinesterase Family"),p(HGNC:GRIN1)) -> bp(GO:"positive regulation of calcium ion import")
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> bp(GO:memory)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> bp(GO:"long-term synaptic potentiation")
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -| bp(GO:"regulation of synaptic activity")
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -| a(CHEBI:"glutamate(2-)")
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> bp(GO:neurogenesis)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -| p(HGNC:GRIA1)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -| p(HGNC:GRIA2)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -| p(HGNC:GRIA3)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -| p(HGNC:GRIA4)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -| p(HGNC:GRIN2A)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -| p(HGNC:GRIN2B)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -| p(HGNC:GRIN2C)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -| p(HGNC:GRIN2D)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -| p(HGNC:GRIN3A)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -| p(HGNC:GRIN3B)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -- bp(GO:"neuron homeostasis")
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> bp(GO:"brain development")
# PyBEL000 general parser failure: a(insulin) -> act(p(HGNC:INSR))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> act(p(HGNC:IRS1,pmod(P,T)))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> act(p(HGNC:IRS2,pmod(P,T)))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> act(p(HGNC:SHC1,pmod(P,T)))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> act(p(HGNC:SHC2,pmod(P,T)))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> act(p(HGNC:SHC3,pmod(P,T)))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> act(p(HGNC:SHC4,pmod(P,T)))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> act(p(HGNC:IGF1))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> p(HGNC:GSK3B,pmod(P,S,9))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> p(PFH:"CREB Family",pmod(P))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> bp(GO:"ERK1 and ERK2 cascade")
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> bp(GO:"positive regulation of calcium-mediated signaling")
# PyBEL000 general parser failure: a("Amyloid beta-Peptides")  -> a(CHEBI:"calcium(2+)")
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> bp(GO:"positive regulation of synaptic plasticity")
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> bp(GO:memory)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> a(CHEBI:"glutamate(2-)")
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> bp(GO:"positive regulation of synaptic plasticity")
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> bp(GO:"negative regulation of neuron apoptotic process")
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -- p(HGNC:CACNG1)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -- p(HGNC:CACNG2)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -- p(HGNC:CACNG3)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -- p(HGNC:CACNG4)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -- p(HGNC:CACNG5)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -- p(HGNC:CACNG6)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -- p(HGNC:CACNG7)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -- p(HGNC:CACNG8)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -- p(HGNC:TRPC1)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -- p(HGNC:TRPC2)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -- p(HGNC:TRPC3)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -- p(HGNC:TRPC4)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -- p(HGNC:TRPC5)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -- p(HGNC:TRPC6)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -- p(HGNC:TRPC7)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -- p(HGNC:CACNG1)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -- p(HGNC:CACNG2)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -- p(HGNC:CACNG3)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -- p(HGNC:CACNG4)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -- p(HGNC:CACNG5)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -- p(HGNC:CACNG7)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -- p(HGNC:CACNG8)
# PyBEL000 general parser failure: p(PFH:"CREB Family",pmod(P,133,S)) -> bp(GO:"positive regulation of CREB transcription factor activity")
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -- bp(GO:"cholesterol transport")
# PyBEL000 general parser failure: complex(a("Amyloid beta-Peptides"),p(HGNC:APOE)) ->  bp(GO:"cholesterol transport")
# PyBEL000 general parser failure: complex(a("Amyloid beta-Peptides"),p(HGNC:APOE)) -> bp(GO:"positive regulation of synapse assembly")
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -| a(CHEBI:"iron(3+)")
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -| a(CHEBI:"copper(2+)")
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -| bp(GO:"phospholipid-hydroperoxide glutathione peroxidase activity")
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -- act(p(HGNC:GRIN2A))   # NMDAR
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -- act(p(HGNC:GRIN2B))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -- act(p(HGNC:GRIN2C))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -- act(p(HGNC:GRIN2D))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -- act(p(HGNC:GRIN3A))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -- act(p(HGNC:GRIN3B))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -- act(p(HGNC:PPID))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -- act(p(HGNC:HSD17B10))  # ABAD
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> bp(GO:"calcium ion import")
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> a(CHEBI:"calcium(2+)")
# PyBEL000 general parser failure: g(HGNC:VLDLR, pmod(U)) -> deg(g(HGNC:VLDLR))
# PyBEL000 general parser failure: g(HGNC:LRP8,pmod(U)) -> deg(g(HGNC:LRP8))
# PyBEL000 general parser failure: reaction(reactants(p(HGNC:APP)),products(a("sAPP-alpha")))
# PyBEL000 general parser failure: a("sAPP-alpha") -> a(CHEBI:"3',5'-cyclic GMP")
# PyBEL000 general parser failure: a("sAPP-alpha") -> bp(GO:"potassium channel activity")
# PyBEL000 general parser failure: a("sAPP-alpha") -- act(p(HGNC:GRIN2C))
# PyBEL000 general parser failure: a("sAPP-alpha") -- tscript(p(HGNC:NFKBIB))
# PyBEL000 general parser failure: reaction(reactants(p(HGNC:APP)),products(a("sAPP-alpha")))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> bp(GO:"neuron development")
# PyBEL000 general parser failure: a("sAPP-alpha") -> bp(GO:"neuronal signal transduction")
# PyBEL000 general parser failure: a("sAPP-alpha") -> bp(GO:"regulation of synaptic transmission, glutamatergic")
# PyBEL000 general parser failure: a("sAPP-alpha") -> bp(GO:"regulation of synaptic plasticity")
# PyBEL000 general parser failure: a("sAPP-alpha") -> act(p(HGNC:NOTCH1))
# PyBEL000 general parser failure: a("sAPP-alpha") -> bp(GO:"glial cell differentiation")
# PyBEL000 general parser failure: a("sAPP-alpha") -> act(p(HGNC:NOTCH2))
# PyBEL000 general parser failure: a("sAPP-alpha") -> act(p(HGNC:NOTCH3))
# PyBEL000 general parser failure: a("sAPP-alpha") -> act(p(HGNC:NOTCH4))
# PyBEL000 general parser failure: a("sAPP-alpha") -> p(HGNC:STAT3,pmod(P))
# PyBEL000 general parser failure: a("sAPP-alpha") -> p(HGNC:STAT3,pmod(P))
# PyBEL000 general parser failure: a("sAPP-alpha") -> act(p(HGNC:NOTCH1))
# PyBEL000 general parser failure: a("sAPP-alpha") ->  act(p(HGNC:NOTCH2))
# PyBEL000 general parser failure: a("sAPP-alpha") -> act(p(HGNC:NOTCH3))
# PyBEL000 general parser failure: a("sAPP-alpha") ->  act(p(HGNC:NOTCH4))
# PyBEL000 general parser failure: pep(complex(p(NCH:"gamma Secretase Complex"))) -> reaction(reactants(p(PFH:"NOTCH Family")),products(a(NICD)))
# PyBEL000 general parser failure: pep(complex(p(NCH:"gamma Secretase Complex"))) -> reaction(reactants(p(HGNC:NOTCH1)),products(a(NICD)))
# PyBEL000 general parser failure: pep(complex(p(NCH:"gamma Secretase Complex"))) -> reaction(reactants(p(HGNC:NOTCH2)),products(a(NICD)))
# PyBEL000 general parser failure: pep(complex(p(NCH:"gamma Secretase Complex"))) -> reaction(reactants(p(HGNC:NOTCH3)),products(a(NICD)))
# PyBEL000 general parser failure: pep(complex(p(NCH:"gamma Secretase Complex"))) -> reaction(reactants(p(HGNC:NOTCH4)),products(a(NICD)))
# PyBEL000 general parser failure: complex(p(NCH:"gamma Secretase Complex")) hasComponents list(p(HGNC:PSEN1),p(HGNC:NCSTN),p(HGNC:APH1A),p(HGNC:PSEN2))
# PyBEL000 general parser failure: complex(a(NICD),p(HGNC:RBPJL)) ->  act(p(HGNC:HES1))              #RBPJL= CBF1/Su(H)/Lag-1 (CSL)
# PyBEL000 general parser failure: complex(a(NICD),p(HGNC:RBPJL)) ->  act(p(HGNC:HES2))
# PyBEL000 general parser failure: complex(a(NICD),p(HGNC:RBPJL)) ->  act(p(HGNC:HES3))
# PyBEL000 general parser failure: complex(a(NICD),p(HGNC:RBPJL)) ->  act(p(HGNC:HES4))
# PyBEL000 general parser failure: complex(a(NICD),p(HGNC:RBPJL)) ->  act(p(HGNC:HES5))
# PyBEL000 general parser failure: complex(a(NICD),p(HGNC:RBPJL)) ->  act(p(HGNC:HES6))
# PyBEL000 general parser failure: complex(a(NICD),p(HGNC:RBPJL)) ->  act(p(HGNC:HES7))
# PyBEL000 general parser failure: reaction(reactants(p(HGNC:APP)),products(a("YENPTY endocytosis motif (APP)")))
# PyBEL000 general parser failure: a("YENPTY endocytosis motif (APP)") -| a("Amyloid beta-Peptides")
# PyBEL000 general parser failure: a("YENPTY endocytosis motif (APP)") -- p(HGNC:APBB1)
# PyBEL000 general parser failure: a("YENPTY endocytosis motif (APP)") -- p(HGNC:APBB2)
# PyBEL000 general parser failure: a("YENPTY endocytosis motif (APP)") -- p(HGNC:APBB3)
# PyBEL000 general parser failure: a("YENPTY endocytosis motif (APP)") -- p(HGNC:APBA1)
# PyBEL000 general parser failure: a("YENPTY endocytosis motif (APP)") -- p(HGNC:APBA2)
# PyBEL000 general parser failure: a("YENPTY endocytosis motif (APP)") -- p(HGNC:APBA3)
# PyBEL000 general parser failure: a("YENPTY endocytosis motif (APP)") -- p(HGNC:DAB1)
# PyBEL000 general parser failure: a("YENPTY endocytosis motif (APP)") -- p(HGNC:MAPK8)
# PyBEL000 general parser failure: a("YENPTY endocytosis motif (APP)") -- p(HGNC:MAPK9)
# PyBEL000 general parser failure: a("YENPTY endocytosis motif (APP)") -- p(HGNC:MAPK10)
# PyBEL000 general parser failure: reaction(reactants(p(HGNC:APP)),products(p(AICD)))
# PyBEL000 general parser failure: complex(p(HGNC:APBB1),p(AICD),p(HGNC:KAT8)) -> act(p(HGNC:LGALS4))     #Gal4 = LGALS4
# PyBEL000 general parser failure: complex(p(AICD),p(HGNC:APBB1),p(HGNC:TFCP2)) -> act(p(HGNC:GSK3B))      # TFCP2 = CP2
# PyBEL000 general parser failure: p(AICD) -- tscript(p(HGNC:APP))
# PyBEL000 general parser failure: p(AICD) -> bp(GO:"regulation of transcription, DNA-dependent")
# PyBEL000 general parser failure: p(HGNC:APP,pmod(P,682,Y)) -> bp(GO:"neuron develpoment")
# PyBEL000 general parser failure: reaction(reactants(p(HGNC:APP)),products(a("N-APP")))
# PyBEL000 general parser failure: a("N-APP") -- p(HGNC:TNFRSF21)
# PyBEL000 general parser failure: a("N-APP") -> bp(GO:"neuron remodeling")
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -- p(HGNC:PRNP)
# PyBEL000 general parser failure: complex(a("N-APP"),p(HGNC:TNFRSF21)) -> bp(GO:"neuron remodeling")
# PyBEL000 general parser failure: a(Microglia) =| a("Amyloid beta-Peptides")
# PyBEL000 general parser failure: a(Microglia) -> p(HGNC:GDNF)
# PyBEL000 general parser failure: reaction(reactants(p(HGNC:APP)),products(a("sAPP-beta")))
# PyBEL000 general parser failure: a("sAPP-beta") -- g(HGNC:TTR)      #TTR = transthyretin
# PyBEL000 general parser failure: a("sAPP-beta") -- g(HGNC:KL)       # KL = Klotho
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> bp(GO:"positive regulation of synaptic plasticity")
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> bp(GO:"long-term synaptic potentiation")
# PyBEL000 general parser failure: p(AICD) -- p(HGNC:KLC1)
# PyBEL000 general parser failure: p(AICD) -- p(HGNC:KLC2)
# PyBEL000 general parser failure: p(AICD) -- p(HGNC:KLC3)
# PyBEL000 general parser failure: p(AICD) -- p(HGNC:KLC4)
# PyBEL000 general parser failure: p(AICD) -- p(HGNC:APBB1)
# PyBEL000 general parser failure: p(AICD) -- p(HGNC:SHC1)
# PyBEL000 general parser failure: p(AICD) -- p(HGNC:SHC2)
# PyBEL000 general parser failure: p(AICD) -- p(HGNC:SHC3)
# PyBEL000 general parser failure: p(AICD) -- p(HGNC:SHC4)
# PyBEL000 general parser failure: p(AICD) -- p(HGNC:MIPK8IA3)
# PyBEL000 general parser failure: p(AICD) -- p(HGNC:NUMB)
# PyBEL000 general parser failure: p(AICD) -- p(HGNC:APBA1)
# PyBEL000 general parser failure: p(AICD) -- p(HGNC:APBA2)
# PyBEL000 general parser failure: p(AICD) -- p(HGNC:APBA3)
# PyBEL000 general parser failure: p(AICD) -- p(HGNC:CLTA)
# PyBEL000 general parser failure: p(AICD) -- p(HGNC:CLTB)
# PyBEL000 general parser failure: p(AICD) -- p(HGNC:CLTC)
# PyBEL000 general parser failure: p(AICD) -- p(HGNC:DAB1)
# PyBEL000 general parser failure: p(AICD) -- p(HGNC:APPBP2)
# PyBEL000 general parser failure: p(AICD) -- p(HGNC:SUV39H1)
# PyBEL000 general parser failure: p(AICD) -- p(HGNC:SUV39H2)
# PyBEL000 general parser failure: p(AICD) -- p(HGNC:SUV420H1)
# PyBEL000 general parser failure: p(AICD) -- p(HGNC:SUV420H1)
# PyBEL000 general parser failure: p(AICD) -- p(HGNC:EZH1)
# PyBEL000 general parser failure: p(AICD) -- p(HGNC:EZH2)
# PyBEL000 general parser failure: p(AICD) -- p(HGNC:EZH2P1)
# PyBEL000 general parser failure: p(AICD) -- p(HGNC:MLLT6)
# PyBEL000 general parser failure: p(AICD) -- p(HGNC:MLLT10P1)
# PyBEL000 general parser failure: p(AICD) -- p(HGNC:MLLT1)
# PyBEL000 general parser failure: p(AICD) -- p(HGNC:MLLT3)
# PyBEL000 general parser failure: p(AICD) -- p(HGNC:MLLT4)
# PyBEL000 general parser failure: p(AICD) -- p(HGNC:MLLT10P2)
# PyBEL000 general parser failure: p(AICD) -- p(HGNC:MLLT11)
# PyBEL000 general parser failure: p(AICD) -- p(HGNC:MLLT10)
# PyBEL000 general parser failure: p(AICD) -- p(HGNC:MLL)
# PyBEL000 general parser failure: p(AICD) -- p(HGNC:MLLT6)
# PyBEL000 general parser failure: p(AICD,pmod(P,T,654)) -| act(p(AICD))
# PyBEL000 general parser failure: complex(p(AICD),p(HGNC:APBB1),p(HGNC:KAT5)) -> bp(GO:"transcription, DNA-dependent")
# PyBEL000 general parser failure: complex(p(AICD),p(HGNC:APBB1),p(HGNC:KAT5)) -> tloc(p(AICD), MESHCL:Cytoplasm,MESHCL:"Cell Nucleus")
# PyBEL000 general parser failure: tloc(p(AICD), MESHCL:Cytoplasm,MESHCL:"Cell Nucleus") -- g(HGNC:CD82)
# PyBEL000 general parser failure: tloc(p(AICD), MESHCL:Cytoplasm,MESHCL:"Cell Nucleus") -- g(HGNC:MMEL1)
# PyBEL000 general parser failure: tloc(p(AICD), MESHCL:Cytoplasm,MESHCL:"Cell Nucleus") -- g(HGNC:LRP1)
# PyBEL000 general parser failure: tloc(p(AICD), MESHCL:Cytoplasm,MESHCL:"Cell Nucleus") -- g(HGNC:TP53)
# PyBEL000 general parser failure: tloc(p(AICD), MESHCL:Cytoplasm,MESHCL:"Cell Nucleus") -- g(HGNC:GSK3B)
# PyBEL000 general parser failure: tloc(p(AICD), MESHCL:Cytoplasm,MESHCL:"Cell Nucleus") -- g(PFH:"EGFR/ERBB Family")
# PyBEL000 general parser failure: complex(p(AICD),p(HGNC:APBB1),p(HGNC:TFCP2)) -- act(g(HGNC:GSK3B))
# PyBEL000 general parser failure: complex(p(AICD),p(HGNC:APBA1)) -- tloc(p(HGNC:APP))
# PyBEL000 general parser failure: complex(p(AICD),p(HGNC:APBA1)) -| a("Amyloid beta-Peptides")
# PyBEL000 general parser failure: complex(p(AICD),p(HGNC:MAPK8IP1)) -> p(HGNC:APP,pmod(P,668,T))
# PyBEL000 general parser failure: complex(p(AICD),p(HGNC:MAPK8IP2)) -> p(HGNC:APP,pmod(P,668,T))
# PyBEL000 general parser failure: complex(p(AICD),p(HGNC:MAPK8IP3)) -> p(HGNC:APP,pmod(P,668,T))
# PyBEL000 general parser failure: g(HGNC:APP,pmod(A,673,T)) =| path(MESHD:"Alzheimer Disease")
# PyBEL000 general parser failure: g(HGNC:APP,pmod(A,T,673)) =| path(MESHD:"Alzheimer Disease")
# PyBEL000 general parser failure: p("adrenergic receptor alpha") hasMembers list(p(HGNC:ADRA1A),p(HGNC:ADRA1B),p(HGNC:ADRA1D),p(HGNC:ADRA2A),p(HGNC:ADRA2B),p(HGNC:ADRA2C))
# PyBEL000 general parser failure: a("Amyloid beta-peptides") -> bp(GO:vasoconstriction)
# PyBEL000 general parser failure: a("Amyloid beta-peptides") -| bp(GO:vasodilation)
# PyBEL000 general parser failure: a("Amyloid beta-peptides") -| bp(GO:"nitric oxide-cGMP-mediated signaling pathway")
# PyBEL000 general parser failure: a("cGMP phosphodiesterase inhibitor") isA a(CHEBI:"phosphodiesterase inhibitor")
# PyBEL000 general parser failure: a("Amyloid beta-peptides") -| a(CHEBI:"3',5'-cyclic GMP")
# PyBEL000 general parser failure: a("Amyloid beta-peptides") -> bp(GO:"leukotriene production involved in inflammatory response")
# PyBEL000 general parser failure: a("Amyloid beta-peptides") -> bp(GO:"inflammatory response")
# PyBEL000 general parser failure: a("Amyloid beta-peptides") -> path(MESHD:"Inflammation")
# PyBEL000 general parser failure: a(cerebrolysin) isA p("neurotrophic factors")
# PyBEL000 general parser failure: a(cerebrolysin) hasMembers list(p(HGNC:BDNF),p(HGNC:GDNF),p(HGNC:NGF),p(HGNC:CNTF))
# PyBEL000 general parser failure: a(cerebrolysin) -- a("Amyloid beta-peptides")
# PyBEL000 general parser failure: a(cerebrolysin) -- path(MESHD:"Inflammation")
# PyBEL000 general parser failure: a(cerebrolysin) -- bp(MESHPP:"Oxidative Stress")
# PyBEL000 general parser failure: a(cerebrolysin) -- bp(GO:"synaptic transmission")
# PyBEL000 general parser failure: a(cerebrolysin) -- bp(MESHPP:"Metabolism")
# PyBEL000 general parser failure: a(cerebrolysin) -- bp(MESHPP:"Neuronal Plasticity")
# PyBEL000 general parser failure: a(cerebrolysin) -- bp(GO:"neuron apoptosis")
# PyBEL000 general parser failure: a(cerebrolysin) -- path(MESHD:"Nerve Degeneration")
# PyBEL000 general parser failure: a(cerebrolysin) -- bp(MESHPP:"Neurogenesis")
# PyBEL000 general parser failure: a(cerebrolysin) -- bp(GO:cognition)
# PyBEL000 general parser failure: a(cerebrolysin) -> bp("PI3K-Akt signaling pathway")
# PyBEL000 general parser failure: a(cerebrolysin) -> bp("glycogen synthase kinase-3 beta intracellular signaling pathway")
# PyBEL000 general parser failure: a(cerebrolysin) -| path(MESHD:"Alzheimer Disease")
# PyBEL000 general parser failure: a(cerebrolysin) -| a("Amyloid beta-peptides")
# PyBEL000 general parser failure: a(cerebrolysin) -| p(MGI:App)
# PyBEL000 general parser failure: a(cerebrolysin) causesNoChange p(MGI:Bace1)
# PyBEL000 general parser failure: a(cerebrolysin) causesNoChange p(MGI:Notch1)
# PyBEL000 general parser failure: a(cerebrolysin) causesNoChange p(MGI:Mme)
# PyBEL000 general parser failure: a(cerebrolysin) causesNoChange p(MGI:Ide)
# PyBEL000 general parser failure: a(cerebrolysin) -| p(MGI:Cdk5)
# PyBEL000 general parser failure: a(cerebrolysin) -| p(MGI:Gsk3b)
# PyBEL000 general parser failure: a(cerebrolysin) -| p(MGI:App,pmod(P))
# PyBEL000 general parser failure: a(cerebrolysin) -| tloc(p(MGI:App), MESHCL:"Cell Surface Extensions", MESHCL:Endosomes)
# PyBEL000 general parser failure: a(cerebrolysin) -| bp(GO:"beta-amyloid formation")
# PyBEL000 general parser failure: a(cerebrolysin) -> bp(GO:cognition)
# PyBEL000 general parser failure: p("AMPA receptor") hasMembers list(p(HGNC:GRIA1), p(HGNC:GRIA2), p(HGNC:GRIA3), p(HGNC:GRIA4))
# PyBEL000 general parser failure: act(p("AMPA receptor")) positiveCorrelation bp(GO:learning)
# PyBEL000 general parser failure: act(p("AMPA receptor")) -> bp(GO:"synaptic transmission")
# PyBEL000 general parser failure: a(cerebrolysin) -> p(MGI:Gria1)
# PyBEL000 general parser failure: a(cerebrolysin) -> bp(GO:"learning or memory")
# PyBEL000 general parser failure: a(cerebrolysin) -| p(HGNC:TNF)
# PyBEL000 general parser failure: a(cerebrolysin) -> p(HGNC:IGF1)
# PyBEL000 general parser failure: a(cerebrolysin) positiveCorrelation path(MESHD:Dizziness)
# PyBEL000 general parser failure: a(cerebrolysin) -| a("Amyloid beta-peptides")
# PyBEL000 general parser failure: a(cerebrolysin) -> bp(GO:"positive regulation of synaptic plasticity")
# PyBEL000 general parser failure: a(cerebrolysin) -> p(MGI:Ngf)
# PyBEL000 general parser failure: complex(a(CHEBI:galanthamine), p(nAChRs)) -> act(p(nAChRs))
# PyBEL000 general parser failure: complex(a(CHEBI:memantine),p(NMDAR)) -| bp(GO:"calcium ion transport into cytosol")
# PyBEL000 general parser failure: a(maprotiline) -> p(HGNC:IL1B)
# PyBEL000 general parser failure: p("adrenergic receptor alpha") hasMembers list(p(HGNC:ADRA1A),p(HGNC:ADRA1B),p(HGNC:ADRA1D),p(HGNC:ADRA2A),p(HGNC:ADRA2B),p(HGNC:ADRA2C))
# PyBEL000 general parser failure: p("adrenergic receptor beta") hasMembers list(p(HGNC:ADRB1),p(HGNC:ADRB2),p(HGNC:ADRB3))
# PyBEL000 general parser failure: p("cholinergic receptor") hasMembers list(p(nAChRs),p(mAChRs))
# PyBEL000 general parser failure: p(nAChRs) hasMembers list(p(HGNC:CHRNA2), p(HGNC:CHRNA3), p(HGNC:CHRNA4), p(HGNC:CHRNA5), p(HGNC:CHRNA6), p(HGNC:CHRNA7), p(HGNC:CHRNA9),
# PyBEL000 general parser failure: p(mAChRs) hasMembers list(p(HGNC:CHRM1), p(HGNC:CHRM2), p(HGNC:CHRM3), p(HGNC:CHRM4), p(HGNC:CHRM5))
# PyBEL000 general parser failure: p("GABA receptor") hasMembers list(p("GABAA receptor"), p("GABAB receptor"))
# PyBEL000 general parser failure: p("GABAA receptor") hasMembers list(p(HGNC:GABRA1), p(HGNC:GABRA2), p(HGNC:GABRA3), p(HGNC:GABRA4), p(HGNC:GABRA5), p(HGNC:GABRA6),
# PyBEL000 general parser failure: p("GABAB receptor") hasMembers list(p(HGNC:GABBR1), p(HGNC:GABBR2))
# PyBEL000 general parser failure: p("dopaminergic receptor") hasMembers list(p(HGNC:DRD1), p(HGNC:DRD2), p(HGNC:DRD3), p(HGNC:DRD4), p(HGNC:DRD5))
# PyBEL000 general parser failure: p("histamine receptor") hasMembers list(p(HGNC:HRH1), p(HGNC:HRH2), p(HGNC:HRH3), p(HGNC:HRH4))
# PyBEL000 general parser failure: a("Etazolate hydrochloride") isA a(CHEBI:"GABA modulator")
# PyBEL000 general parser failure: a("Etazolate hydrochloride") -> a(sAPPalpha)
# PyBEL000 general parser failure: a("Amyloid beta-peptides") -- bp(GO:"neuron death")
# PyBEL000 general parser failure: a(sAPPalpha) -| act(a("Amyloid beta-peptides"))
# PyBEL000 general parser failure: a(molindone) isA a(CHEBI:"dopaminergic antagonist")
# PyBEL000 general parser failure: a(molindone) -| act(p(HGNC:DRD2))
# PyBEL000 general parser failure: a(molindone) -| act(p(HGNC:DRD2))
# PyBEL000 general parser failure: a(molindone) -| act(p(HGNC:HTR1A))
# PyBEL000 general parser failure: a(molindone) -| act(p(HGNC:HTR2A))
# PyBEL000 general parser failure: a(molindone) -| act(p(HGNC:CHRM1))
# PyBEL000 general parser failure: a(molindone) positiveCorrelation p(HGNC:PRL)
# PyBEL000 general parser failure: p("adrenergic receptor alpha") hasMembers list(p(HGNC:ADRA1A),p(HGNC:ADRA1B),p(HGNC:ADRA1D),p(HGNC:ADRA2A),p(HGNC:ADRA2B),p(HGNC:ADRA2C))
# PyBEL000 general parser failure: p("adrenergic receptor beta") hasMembers list(p(HGNC:ADRB1),p(HGNC:ADRB2),p(HGNC:ADRB3))
# PyBEL000 general parser failure: path(depression) positiveCorrelation path(MESHD:"Alzheimer Disease")
# PyBEL000 general parser failure: a(Methoctramine) isA a(CHEBI:"muscarinic antagonist")
# PyBEL000 general parser failure: a(Methoctramine) -| (act(a(SCHEM:Arecoline)) -> bp(GO:"rhythmic excitation"))
# PyBEL000 general parser failure: complex("HPA axis") hasMembers list(a(hypothalamus),a("pituitary gland"),a("adrenal gland"))
# PyBEL000 general parser failure: p(mAChRs) hasMembers list(p(HGNC:CHRM1), p(HGNC:CHRM2), p(HGNC:CHRM3), p(HGNC:CHRM4), p(HGNC:CHRM5))
# PyBEL000 general parser failure: act(complex("HPA axis")) -> a(CHEBI:corticotropin)
# PyBEL000 general parser failure: act(complex("HPA axis")) -> a(CHEBI:cortisol)
# PyBEL000 general parser failure: act(complex("HPA axis")) -> a(CHEBI:vasopressin)
# PyBEL000 general parser failure: act(complex("HPA axis")) -> a(SCHEM:Epinephrine)
# PyBEL000 general parser failure: a(Neuropeptide) hasMembers list(a(CHEBI:corticotropin),a(CHEBI:cortisol), a(CHEBI:vasopressin), a(SCHEM:Epinephrine))
# PyBEL000 general parser failure: a(Neuropeptide) -> bp(GO:"synaptic transmission")
# PyBEL000 general parser failure: a(Neuropeptide) -> bp(GO:cognition)
# PyBEL000 general parser failure: a(Tarenflurbil) isA a(CHEBI:"(R)-flurbiprofen")
# PyBEL000 general parser failure: a("Amyloid beta-peptides") causesNoChange path(MESHD:"Alzheimer Disease")
# PyBEL000 general parser failure: a("Amyloid beta-peptides") -> bp(GO:"neuron apoptotic process")
# PyBEL000 general parser failure: a("gamma secretase inhibitor") -| pep(complex(NCH:"gamma secretase Complex"))
# PyBEL000 general parser failure: a("gamma secretase inhibitor") -| bp(GO:"positive regulation of Notch signaling pathway")
# PyBEL000 general parser failure: a(Etazolate) isA a(CHEBI:"GABA modulator")
# PyBEL000 general parser failure: a(Etazolate) -> a(sAPPalpha)
# PyBEL000 general parser failure: a(Etazolate) -> bp(GO:"neuroprotection")
# PyBEL000 general parser failure: a(Etazolate) -> a(sAPPalpha)
# PyBEL000 general parser failure: a(sAPPalpha) -> bp(GO:"neuroprotection")
# PyBEL000 general parser failure: a(Etazolate) isA a(CHEBI:"phosphodiesterase inhibitor")
# PyBEL000 general parser failure: a(Etazolate) -> pep(p(HGNC:"ADAM10"))
# PyBEL000 general parser failure: a(Etazolate) -> a(sAPPalpha)
# PyBEL000 general parser failure: a(Etazolate) -> bp(GO:"learning or memory")
# PyBEL000 general parser failure: a("Etazolate hydrochloride") isA a(CHEBI:"GABA modulator")
# PyBEL000 general parser failure: a("Etazolate hydrochloride") isA a(CHEBI:"phosphodiesterase inhibitor")
# PyBEL000 general parser failure: a("Etazolate hydrochloride") -> pep(p(HGNC:"ADAM10"))
# PyBEL000 general parser failure: a("Etazolate hydrochloride") -> a(sAPPalpha)
# PyBEL000 general parser failure: a(Nefiracetam) -> bp(GO:cognition)
# PyBEL000 general parser failure: a(Nefiracetam) -> bp(GO:cognition)
# PyBEL000 general parser failure: p(NMDAR) hasMembers list(p(HGNC:GRIN1), p(HGNC:GRIN2A), p(HGNC:GRIN2B), p(HGNC:GRIN2C), p(HGNC:GRIN2D), p(HGNC:GRIN3A), p(HGNC:GRIN3B))
# PyBEL000 general parser failure: p(nAChRs) hasMembers list(p(HGNC:CHRNA2), p(HGNC:CHRNA3), p(HGNC:CHRNA4), p(HGNC:CHRNA5), p(HGNC:CHRNA6), p(HGNC:CHRNA7), p(HGNC:CHRNA9),
# PyBEL000 general parser failure: a(Nefiracetam) -> act(p(NMDAR))
# PyBEL000 general parser failure: a(Nefiracetam) -> act(p(nAChRs))
# PyBEL000 general parser failure: a(Nefiracetam)  -> act(p(HGNC:PRKCA))
# PyBEL000 general parser failure: a(Nefiracetam) causesNoChange bp(GO:"protein kinase A signaling cascade")
# PyBEL000 general parser failure: a(Nefiracetam)  ->  act(p(nAChRs))
# PyBEL000 general parser failure: a(galantamine) -> act(p(nAChRs))
# PyBEL000 general parser failure: act(p(nAChRs)) -> a(CHEBI:"gamma-aminobutyric acid")
# PyBEL000 general parser failure: act(p(nAChRs)) -> a(CHEBI:"glutamate(1-)")
# PyBEL000 general parser failure: a(Nefiracetam) isA a(CHEBI:"acetylcholinesterase inhibitor")
# PyBEL000 general parser failure: a(Nefiracetam) -> bp(GO:cognition)
# PyBEL000 general parser failure: a(Nefiracetam) -> bp(GO:"long-term synaptic potentiation")
# PyBEL000 general parser failure: a(Nefiracetam) -- (act(complex(NCH:"CAMK2 Complex")) -- p(HGNC:GRIA1, pmod(P,S,831)))
# PyBEL000 general parser failure: a(Nefiracetam) -> act(p(NMDAR))
# PyBEL000 general parser failure: a(Nefiracetam) -> act(complex(NCH:"CAMK2 Complex"))
# PyBEL000 general parser failure: p(NMDAR) -> bp(GO:cognition)
# PyBEL000 general parser failure: p(NMDAR) -> bp(GO:learning)
# PyBEL000 general parser failure: p(NMDAR) -> bp(GO:memory)
# PyBEL000 general parser failure: p(PKC) hasMembers list(p(HGNC:PRKCA), p(HGNC:PRKCB), p(HGNC:PRKCD), p(HGNC:PRKCE), p(HGNC:PRKCG), p(HGNC:PRKCH), p(HGNC:PRKCI), p(HGNC:PRKCQ), p(HGNC:PRKCZ))
# PyBEL000 general parser failure: a(Nefiracetam) -> complex(a(Nefiracetam),p(PKC))
# PyBEL000 general parser failure: complex(a(Nefiracetam),p(PKC)) -> act(p(nAChRs))
# PyBEL000 general parser failure: act(p(nAChRs)) -> a(CHEBI:"glutamate(1-)")
# PyBEL000 general parser failure: a(Nefiracetam) -> bp(GO:cognition)
# PyBEL000 general parser failure: a("Amyloid beta-peptides") -> act(complex(NCH:"Nfkb Complex"))
# PyBEL000 general parser failure: complex(NCH:"Nfkb Complex") hasMembers list(p(HGNC:RELA), p(HGNC:NFKB1))
# PyBEL000 general parser failure: composite(a("Amyloid beta-peptides"), p(HGNC:IFNG)) -> tloc(p(HGNC:RELA), MESHCL:Cytosol, MESHCL:"Cell Nucleus")
# ...
# PyBEL000 general parser failure: p(PFM:"Mapk p38 Family") hasMembers list(p(MGI:Mapk11),p(MGI:Mapk12),p(MGI:Mapk13),p(MGI:Mapk14))
# PyBEL000 general parser failure: p(PKC) hasMembers list(p(HGNC:PRKCA), p(HGNC:PRKCB), p(HGNC:PRKCD), p(HGNC:PRKCE), p(HGNC:PRKCG), p(HGNC:PRKCH),
# PyBEL000 general parser failure: p(PKC) -> bp(GO:"apoptotic process")
# PyBEL000 general parser failure: p(PKC) hasMembers list(p(HGNC:PRKCA), p(HGNC:PRKCB), p(HGNC:PRKCD), p(HGNC:PRKCE), p(HGNC:PRKCG), p(HGNC:PRKCH),
# PyBEL000 general parser failure: p(PKC) -> bp(GO:"apoptotic process")
# PyBEL000 general parser failure: complex(p(HGNC:ACHE), a("Amyloid beta-peptides")) -> a("Amyloid beta-peptides")
# PyBEL000 general parser failure: a(sAPPalpha)-> bp(GO:neuroprotection)
# PyBEL000 general parser failure: bp(astrogliosis) -> p(HGNC:BACE1)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> p(HGNC:HMOX1)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> bp(astrogliosis)
# PyBEL000 general parser failure: bp(astrogliosis) -> composite(a(cytokines), a(chemokines), a(prostagladins),a("reactive oxygen species"), a(CHEBI:"nitric oxide"))
# PyBEL000 general parser failure: bp(astrogliosis) -> composite(a(cytokines), a(chemokines), a(prostagladins),a("reactive oxygen species"), a(CHEBI:"nitric oxide"))
# PyBEL000 general parser failure: composite(a(cytokines), a(chemokines)) -> p(HGNC:COX5A)
# PyBEL000 general parser failure: composite(a(cytokines), a(chemokines)) -> p(HGNC:COX8A)
# PyBEL000 general parser failure: composite(a(cytokines), a(chemokines)) -> p(HGNC:COX2)
# PyBEL000 general parser failure: bp(astrogliosis) -> bp(GO:"inflammatory response")
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> bp(GO:"inflammatory response")
# PyBEL000 general parser failure: bp(astrogliosis) -> (p(HGNC:TNFSF10) -> complex(p(HGNC:TNFSF10), p(HGNC:TNFRSF10B)))
# PyBEL000 general parser failure: a(lysosomes) -> deg(a("Amyloid beta-Peptides"))
# PyBEL000 general parser failure: complex(p(HGNC:AGER),a("Amyloid beta-Peptides"))
# PyBEL000 general parser failure: complex(p(HGNC:S100B),a("Amyloid beta-Peptides"))
# PyBEL000 general parser failure: complex(p(HGNC:HMGB1),a("Amyloid beta-Peptides"))
# PyBEL000 general parser failure: act(a(inflammasome)) -> (a(cytokines) -> bp(GO:pyroptosis))
# PyBEL000 general parser failure: act(a(inflammasome)) -> (p(HGNC:IL1B) -> bp(GO:pyroptosis))
# PyBEL000 general parser failure: act(a(inflammasome)) -> (p(HGNC:IL18) -> bp(GO:pyroptosis))
# PyBEL000 general parser failure: act(a(inflammasome)) -> (p(HGNC:HMGB1) -> bp(GO:pyroptosis))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> (act(p(HGNC:TLR2)) -> bp(GO:"inflammatory response"))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> (act(p(HGNC:TLR4)) -> bp(GO:"inflammatory response"))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> (act(p(HGNC:NOD2)) -> bp(GO:"inflammatory response"))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> (act(p(HGNC:TLR4)) -> bp(GO:"inflammatory response"))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> (act(p(HGNC:FPR1)) -> bp(GO:"inflammatory response"))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> (act(p(HGNC:FPR2)) -> bp(GO:"inflammatory response"))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> (act(p(HGNC:AGER)) -> bp(GO:"inflammatory response"))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> (act(p(HGNC:MSR1)) -> bp(GO:"inflammatory response"))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> (act(p(HGNC:SCARB1)) -> bp(GO:"inflammatory response"))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> (act(p(HGNC:PTX3)) -> bp(GO:"inflammatory response"))
# PyBEL000 general parser failure: a("neurofibrillary tangles") -> bp(GO:"inflammatory response")
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -| p(HGNC:BDNF)
# PyBEL000 general parser failure: a(Platelets) -> a("Amyloid beta-Peptides")
# PyBEL000 general parser failure: complex(a(Platelets), p(HGNC:SELP)) -> a(chemokines)
# PyBEL000 general parser failure: complex(a(Platelets), p(HGNC:SELP)) -> a(interleukins)
# PyBEL000 general parser failure: complex(a(Platelets), p(HGNC:PECAM1)) -> a(chemokines)
# PyBEL000 general parser failure: complex(a(Platelets), p(HGNC:PECAM1)) -> a(interleukins)
# PyBEL000 general parser failure: complex(a(Platelets), p(HGNC:ICAM1)) -> a(chemokines)
# PyBEL000 general parser failure: complex(a(Platelets), p(HGNC:ICAM1)) -> a(interleukins)
# PyBEL000 general parser failure: complex(a(Platelets), p(HGNC:ICAM2)) -> a(chemokines)
# PyBEL000 general parser failure: complex(a(Platelets), p(HGNC:ICAM2)) -> a(interleukins)
# PyBEL000 general parser failure: a(chemokines) -> bp(GO:"inflammatory response")
# PyBEL000 general parser failure: a(interleukins) -> bp(GO:"inflammatory response")
# PyBEL000 general parser failure: a(Platelets) -> (p(HGNC:PLA2G7) -> bp(GO:"inflammatory response"))
# PyBEL000 general parser failure: a(Platelets) -> (p(HGNC:COX2) -> bp(GO:"inflammatory response"))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> (p(HGNC:IL12B) -> bp(GO:"inflammatory response"))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> (p(HGNC:IL23A) -> bp(GO:"inflammatory response"))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> (p(HGNC:CD14) -> bp(GO:"inflammatory response"))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> (p(HGNC:MYD88) -> bp(GO:"inflammatory response"))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> (p(HGNC:TLR2) -> bp(GO:"inflammatory response"))
# PyBEL000 general parser failure: a(Microglia) positiveCorrelation path(neuroinflammation)
# PyBEL000 general parser failure: a(Astrocytes) positiveCorrelation path(neuroinflammation)
# PyBEL000 general parser failure: act(a(Astrocytes)) positiveCorrelation p(HGNC:BCHE)
# PyBEL000 general parser failure: path(neuroinflammation) -> path(MESHD:"Alzheimer Disease")
# PyBEL000 general parser failure: complex(a(Abeta42), p(HGNC:LAMP2)) -> bp(GO:phagocytosis)
# PyBEL000 general parser failure: a(Abeta42) -| sec(p(HGNC:BDNF))
# PyBEL000 general parser failure: complex(a(Microglia), a(Abeta42)) -> p(HGNC:IL1R1)
# PyBEL000 general parser failure: complex(a(Microglia), a(Abeta42)) -> p(HGNC:NOS2)
# PyBEL000 general parser failure: a(isoprostanes) positiveCorrelation path(MESHD:"Alzheimer Disease")
# PyBEL000 general parser failure: a("24S-OH-cholesterol") biomarkerFor path(neurodegeneration)
# PyBEL000 general parser failure: a("alpha(1)-Antichymotripsin") biomarkerFor path(neurodegeneration)
# PyBEL000 general parser failure: p(inflammasome) isA composite(p(HGNC:CASP1),p(HGNC:PYCARD),p("NALP Family"))
# PyBEL000 general parser failure: p(inflammasome) -> p(HGNC:IL1B)
# PyBEL000 general parser failure: p(inflammasome) -> p(HGNC:IL18)
# PyBEL000 general parser failure: p(inflammasome) -> p(HGNC:IL33)
# PyBEL000 general parser failure: path(neuroinflammation) positiveCorrelation p(HGNC:IL1)
# PyBEL000 general parser failure: path(neuroinflammation) positiveCorrelation p(HGNC:IL6)
# PyBEL000 general parser failure: path(neuroinflammation) positiveCorrelation p(HGNC:TNF)
# PyBEL000 general parser failure: p(cytokines) -- complex(path(MESHD:"Neurodegenerative Diseases"))
# PyBEL000 general parser failure: p(cytokines) positiveCorrelation path(MESHD:"Mild Cognitive Impairment")
# PyBEL000 general parser failure: p(cytokines) positiveCorrelation path(MESHD:"Alzheimer Disease")
# PyBEL000 general parser failure: complex(p(HGNC:NFE2L2))
# PyBEL000 general parser failure: a("Physical activity") -| path(MESHD:"Alzheimer Disease")
# PyBEL000 general parser failure: a("Physical activity") -- path(MESHD:"Alzheimer disease")
# PyBEL000 general parser failure: a("Physical activity") -| path(MESHD:"Atrophy")
# PyBEL000 general parser failure: complex(path(MESHD:"Alzheimer Disease"))
# PyBEL000 general parser failure: complex(path(MESHD:Dementia))
# PyBEL000 general parser failure: p(cytokines) -- path(MESHD:"Alzheimer Disease")
# PyBEL000 general parser failure: p(cytokines) -- path(MESHD:"Neurodegenerative Diseasee")
# PyBEL000 general parser failure: p("neurons") -| path(MESHD:"Neurodegenerative Diseases")
# PyBEL000 general parser failure: p("microglia") -> a("Amyloid beta-peptides")
# PyBEL000 general parser failure: a(astrocytes) -> p(HGNC:CSF3R)
# PyBEL000 general parser failure: a(astrocytes) -> p(HGNC:CSF2RB)
# PyBEL000 general parser failure: a(astrocytes) -> p(HGNC:IL6)
# PyBEL000 general parser failure: a(astrocytes) -> p(HGNC:IL8)
# PyBEL000 general parser failure: a(astrocytes) -> p(HGNC:CCL2)
# PyBEL000 general parser failure: a(astrocytes) -> p(HGNC:CCL2)
# PyBEL000 general parser failure: a(astrocytes) -> p(HGNC:MIF)
# PyBEL000 general parser failure: a(astrocytes) -> p(HGNC:SERPINE1)
# PyBEL000 general parser failure: a(astrocytes) -> p(HGNC:CXCL1)
# PyBEL000 general parser failure: a(astrocytes) -> p(HGNC:IL1B)
# PyBEL000 general parser failure: a(astrocytes) -> p(HGNC:IL1RN)
# PyBEL000 general parser failure: a(astrocytes) -> p(HGNC:TNF)
# PyBEL000 general parser failure: a(astrocytes) -> p(HGNC:CXCL10)
# PyBEL000 general parser failure: a(astrocytes) -> p(HGNC:CCL3)
# PyBEL000 general parser failure: a(astrocytes) -> p(HGNC:CCL5)
# PyBEL000 general parser failure: a(astrocytes) -> p(HGNC:ICAM1)
# PyBEL000 general parser failure: a(astrocytes) -> p(HGNC:C5)
# PyBEL000 general parser failure: bp("NF-kB signaling pathway") -- p("cytokines")
# PyBEL000 general parser failure: bp("NF-kB signaling pathway") -- p("chemokines")
# PyBEL000 general parser failure: bp(neuroinflammation) -- path(MESHD:"Alzheimer Disease")
# PyBEL000 general parser failure: bp(neuroinflammation) -> bp(GO:"innate immune response")
# PyBEL000 general parser failure: bp(neuroinflammation) -> bp(GO:"pattern recognition receptor activity")
# PyBEL000 general parser failure: a(astrocytes) -> g(HGNC:APP)
# PyBEL000 general parser failure: a(astrocytes) -> a("amyloid beta peptides")
# PyBEL000 general parser failure: complex(a(CHEBI:"vinyl ether"))
# PyBEL000 general parser failure: complex(bp(GO:"cannabinoid receptor activity"))
# PyBEL000 general parser failure: complex(p(HGNC:CNR2))
# PyBEL000 general parser failure: complex(bp(GO:"cannabinoid receptor activity"),p(HGNC:CNR2))
# PyBEL000 general parser failure: complex(path(MESHD:"Pelizaeus-Merzbacher Disease"))
# PyBEL000 general parser failure: complex(p(MGI:Tlr2), a("Amyloid beta-Peptides"))
# PyBEL000 general parser failure: complex(p(MGI:Tlr2), a("Amyloid beta-Peptides")) -> bp(GO:"inflammatory response")
# PyBEL000 general parser failure: a(Sirtuin) -- path(MESHD:Gliosis)
# PyBEL000 general parser failure: complex(path(MESHD:"Alzheimer Disease"))
# PyBEL000 general parser failure: path(Neuroinflammation) -> path(MESHD:Stroke)
# PyBEL000 general parser failure: path(Neuroinflammation) -> path(MESHD:"Multiple Sclerosis")
# PyBEL000 general parser failure: path(Neuroinflammation) -> path(MESHD:"Brain Injuries")
# PyBEL000 general parser failure: path(Neuroinflammation) -> path(MESHD:"Alzheimer Disease")
# PyBEL000 general parser failure: path(Neuroinflammation) -> path(MESHD:"Parkinson Disease")
# PyBEL000 general parser failure: complex(a(beta_adrenergic receptor),a(CHEBI:noradrenaline)) -| path(MESHD:Inflammation)
# PyBEL000 general parser failure: bp( "GO:inflammatory response") -> (r(MGI:Il1b) -> r(MGI:Nos2))
# PyBEL000 general parser failure: complex(bp(GO:"histone deacetylase activity"))
# PyBEL000 general parser failure: bp(GO:microglial proliferation) -- p(MGI:Runx1t1)
# PyBEL000 general parser failure: complex(bp(GO:"chemokine receptor activity"),p(MGI:Ccl2))
# PyBEL000 general parser failure: complex(p(MGI:Ccl2),bp(GO:"chemokine receptor activity"))
# PyBEL000 general parser failure: complex(path(MESHD:"Alzheimer Disease"),p(MGI:Cr1))
# PyBEL000 general parser failure: complex(p(MGI:Cr1),path(MESHD:"Alzheimer Disease"))
# PyBEL000 general parser failure: p(MGI:App1-42) -> r(MGI:Cysltr1)
# PyBEL000 general parser failure: p(MGI:App1-42) -> r(MGI:Cysltr1)
# PyBEL000 general parser failure: complex(a(CHEBI:"nitric oxide"))
# PyBEL000 general parser failure: a("3NTyr(10)-Aβ") -> path(MESHD:Amyloidosis)
# PyBEL000 general parser failure: complex(path(MESHD:"Plaque, Amyloid"))
# PyBEL000 general parser failure: a(MGI:Tnfα) -> path(MESHD:"Plaque, Amyloid")
# PyBEL000 general parser failure: complex(p(MGI:Cnr2))
# PyBEL000 general parser failure: complex(path(MESHD:"Plaque, Amyloid"))
# PyBEL000 general parser failure: complex(path(MESHD:"Alzheimer Disease"))
# PyBEL000 general parser failure: complex(path(MESHD:"Parkinson Disease"),a(CHEBI:rifampicin))
# PyBEL000 general parser failure: complex(a(CHEBI:"messenger RNA"))
# PyBEL000 general parser failure: complex(a(CHEBI:"beta_amyloid"))
# PyBEL000 general parser failure: complex(path(MESHD:"Alzheimer Disease"))
# PyBEL000 general parser failure: complex(a(CHEBI:"2_7_dichlorofluorescein"))
# PyBEL000 general parser failure: complex(a(CHEBI:"reactive oxygen species"))
# PyBEL000 general parser failure: a("Amyloid beta-peptides") -> path(MESHD:Inflammation)
# PyBEL000 general parser failure: a("Amyloid beta-peptides") -> path(neurotoxicity)
# PyBEL000 general parser failure: complex(bp(GO:"cannabinoid receptor activity"))
# PyBEL000 general parser failure: complex(p(MGI:Cnr2))
# PyBEL000 general parser failure: complex(bp(GO:"cannabinoid receptor activity"),p(MGI:Cnr2))
# PyBEL000 general parser failure: tloc(a("T-Lymphocytes")) -- p(MGI:Cxcr3)
# PyBEL000 general parser failure: tloc(a("T-Lymphocytes")) -- p(MGI:Cxcr3)
# PyBEL000 general parser failure: tloc(a("Natural Killer Cells")) -- p(MGI:Cxcr3)
# PyBEL000 general parser failure: path("chronic CNS injury") -> a(CHEBI:"fatty acid")
# PyBEL000 general parser failure: path("chronic CNS injury") -> a(CHEBI:icosanoid)
# PyBEL000 general parser failure: path("chronic CNS injury") -> bp("lipid peroxidation")
# PyBEL000 general parser failure: a(Astrocytes) -> (bp(GO:"inflammatory response") -> path(MESHD:"Alzheimer Disease"))
# PyBEL000 general parser failure: act(a(Microglia)) positiveCorrelation path(MESHD:"Alzheimer Disease")
# PyBEL000 general parser failure: act(a(Astrocytes)) positiveCorrelation path(MESHD:"Alzheimer Disease")
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> p(MGI:Cox2)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> p(MGI:Il1)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> p(MGI:Il6)
# PyBEL000 general parser failure: act(a(Astrocytes)) -> p(MGI:Gfap)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> p(MGI:Gfap)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> p(MGI:Cox2)
# PyBEL000 general parser failure: act(a(Astrocytes)) -| p(MGI:Pparg)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -| p(MGI:Pparg)
# PyBEL000 general parser failure: act(a(Astrocytes)) -> p(MGI:Cox2)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> tloc(p(MGI:Nfkb1))
# PyBEL000 general parser failure: act(a(Astrocytes)) -> a("Amyloid beta-Peptides")
# PyBEL000 general parser failure: a(Microglia) positiveCorrelation path(MESHD:"Alzheimer Disease")
# PyBEL000 general parser failure: a(Microglia) -> bp(GO:"neuron death")
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> path(MESHD:"Alzheimer Disease")
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -| p(MGI:Chat)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> (a(Microglia) -> bp(GO:"inflammatory response"))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -| bp(GO:"positive regulation of synaptic transmission, cholinergic")
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> p(MGI:Hmox1)
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> (a(Astrocytes) -| bp(GO:"axonogenesis"))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> (a(Neuroglia) -| bp(GO:"axonogenesis"))
# PyBEL000 general parser failure: a("Amyloid beta-Peptides") -> (a(Microglia) -| bp(GO:"axonogenesis"))
# PyBEL000 general parser failure: a(Microglia) -> bp(microgliosis)

# %%
c = Counter(map(itemgetter(0), filter(lambda x:x,g)))
df = pd.DataFrame.from_dict(c, orient='index')
df.sort_values(0, ascending=False).plot(kind='bar')
plt.show()

# %%
ec = Counter(data['relation'] for u, v, data in g.edges(data=True) if 'relation' in data)
df_ec = pd.DataFrame.from_dict(ec, orient='index')
df_ec.sort_values(0, ascending=False).plot(kind='bar')
plt.show()

# %%
plt.figure(figsize=(10.5, 10.5))
nx.draw(g, node_size=10)
