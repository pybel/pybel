# %%
import pybel
import pybel.examples
import logging
logging.basicConfig(level=logging.INFO)

# %%
URL = 'https://cannin.github.io/covid19-sbgn/ER_Stress_Cov19.xml.sbgn'

# %%
g2 = pybel.from_sbgn_url(URL)
# Out:
# INFO:pybel.io.sbgnml.parse:Using SBGN prefix: {http://sbgn.org/libsbgn/0.2}
# INFO:pyobo.normalizer:getting obo normalizer for go
# INFO:pyobo.normalizer:getting obo normalizer for mesh
# WARNING:pyobo.io_utils:bad line: C000607352
#
# WARNING:pyobo.io_utils:bad line: C513170
#
# WARNING:pyobo.io_utils:bad line: C574948
#
# WARNING:pybel.io.sbgnml.parse:could not find Autophgosome [id=c7_ca7] in namespaces ['go', 'mesh']
# INFO:pyobo.normalizer:getting obo normalizer for efo
# INFO:pyobo.normalizer:getting obo normalizer for hp
# INFO:pyobo.normalizer:getting obo normalizer for doid
# WARNING:pybel.io.sbgnml.parse:no references for Persistant ER Stress [id=s305_sa231, class=phenotype]. Failed grounding to go/efo/hp/doid/mesh
# WARNING:pybel.io.sbgnml.parse:no references for UPR [id=s43_sa36, class=phenotype]. Failed grounding to go/efo/hp/doid/mesh
# ...

# %%
pybel.to_jupyter(g2)

# %%
g = pybel.from_sbgn_file('/Users/cthoyt/Downloads/Apoptosis_03.06.2020.xml.sbgn')
# Out:
# INFO:pybel.io.sbgnml.parse:Using SBGN prefix: {http://sbgn.org/libsbgn/0.2}
# WARNING:pybel.io.sbgnml.utils:unhandled urn:miriam resource: mesh:D017209
# INFO:pybel.io.sbgnml.parse:macromolecule s4_sa2 FASLG in {'glyph_id': 'c7_ca7', 'entity': {'prefix': 'go', 'identifier': '0005615', 'name': 'extracellular space'}}
# INFO:pybel.io.sbgnml.parse:macromolecule s5_sa3 TNF in {'glyph_id': 'c7_ca7', 'entity': {'prefix': 'go', 'identifier': '0005615', 'name': 'extracellular space'}}
# INFO:pybel.io.sbgnml.parse:macromolecule s6_sa8 TNFRSF1A in {'glyph_id': 'c4_ca4', 'entity': {'prefix': 'go', 'identifier': '0005886', 'name': 'plasma membrane'}}
# INFO:pybel.io.sbgnml.parse:macromolecule s7_sa5 FAS in {'glyph_id': 'c4_ca4', 'entity': {'prefix': 'go', 'identifier': '0005886', 'name': 'plasma membrane'}}
# INFO:pybel.io.sbgnml.parse:macromolecule s20_sa25 CYCS in {'glyph_id': 'c5_ca5', 'entity': {'prefix': 'go', 'identifier': '0005737', 'name': 'cytoplasm'}}
# ...

# %%
for node in g:
    print(node)
# Out:
# complex(p(hgnc:11920 ! FAS), p(hgnc:11936 ! FASLG))
# p(hgnc:11920 ! FAS)
# p(hgnc:11936 ! FASLG)
# p(hgnc:3573 ! FADD)
# p(hgnc:1509 ! CASP8)
# complex(p(hgnc:12030 ! TRADD), p(hgnc:3573 ! FADD))
# p(hgnc:12030 ! TRADD)
# p(hgnc:1504 ! CASP3)
# p(hgnc:1511 ! CASP9)
# complex(go:0043293 ! apoptosome)
# p(hgnc:391 ! AKT1)
# p(hgnc:1050 ! BID)
# p(hgnc:959 ! BAX)
# complex(p(hgnc:17868 ! BBC3), p(hgnc:936 ! BAD), p(hgnc:994 ! BCL2L11))
# p(hgnc:17868 ! BBC3)
# p(hgnc:936 ! BAD)
# p(hgnc:994 ! BCL2L11)
# complex(p(hgnc:6943 ! MCL1), p(hgnc:990 ! BCL2), p(hgnc:992 ! BCL2L1))
# p(hgnc:6943 ! MCL1)
# p(hgnc:990 ! BCL2)
# p(hgnc:992 ! BCL2L1)
# p(hgnc:6876 ! MAPK14)
# p(hgnc:19986 ! CYCS)
# p(hgnc:1508 ! CASP7)
# p(ncbiprotein:APO40582 ! M)
# complex(p(fplx:TNF ! TNF), p(hgnc:11916 ! TNFRSF1A))
# p(fplx:TNF ! TNF)
# p(hgnc:11916 ! TNFRSF1A)
# bp(pubmed:31226023 ! Apoptosis)
# p(chebi:50347 ! N)
# p(chebi:29830 ! S)

# %%
pybel.to_jupyter(g)

# %%
g3 = pybel.from_sbgn_url(
    'https://git-r3lab.uni.lu/covid/models/-/raw/master/Curation/IL6-AMP/IL6-AMP.AF.nwt',
    version='0.2',
)
# Out:
# INFO:pybel.io.sbgnml.parse:Using SBGN prefix: {http://sbgn.org/libsbgn/0.2}
# WARNING:pybel.io.sbgnml.parse:could not find Bloodstream/Extracellular Space [id=nwtN_d27ebed2-a890-4ee2-b9c4-043e11a8ea6f] in namespaces ['go', 'mesh']
# WARNING:pybel.io.sbgnml.parse:no references for CRS [id=nwtN_a67c1260-780c-4ec6-a0b1-ff23cb0a957d, class=phenotype]. Failed grounding to go/efo/hp/doid/mesh
# WARNING:pybel.io.sbgnml.parse:unhandled class: biological activity: <Element '{http://sbgn.org/libsbgn/0.2}glyph' at 0x13439a220>
# WARNING:pybel.io.sbgnml.parse:unhandled class: biological activity: <Element '{http://sbgn.org/libsbgn/0.2}glyph' at 0x134375040>
# WARNING:pybel.io.sbgnml.parse:unhandled class: biological activity: <Element '{http://sbgn.org/libsbgn/0.2}glyph' at 0x1739ef4a0>
# WARNING:pybel.io.sbgnml.parse:unhandled class: biological activity: <Element '{http://sbgn.org/libsbgn/0.2}glyph' at 0x13447aa90>
# ...

# %%
pybel.to_jupyter(g3)
